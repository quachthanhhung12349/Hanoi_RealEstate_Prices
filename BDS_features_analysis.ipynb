# %%
import math
import re
import pandas as pd

df = pd.read_csv('data/ml/hanoi_real_estate_ml_accessibility.csv')

df
# Out:
#         Mã tin                                               Link  \
# 0     45913112  https://batdongsan.com.vn/ban-dat-thi-tran-quo...
# 1     45910399  https://batdongsan.com.vn/ban-nha-rieng-duong-...
# 2     45909917  https://batdongsan.com.vn/ban-dat-duong-mai-di...
# 3     45741286  https://batdongsan.com.vn/ban-nha-rieng-duong-...
# 4     45736903  https://batdongsan.com.vn/ban-dat-xa-van-canh-...
# ...        ...                                                ...
# 2634  45107786  https://batdongsan.com.vn/ban-dat-duong-o-cach...
# 2635  45663079  https://batdongsan.com.vn/ban-dat-duong-cao-xa...
# 2636  45330438  https://batdongsan.com.vn/ban-dat-duong-tran-h...
# 2637  45651835  https://batdongsan.com.vn/ban-dat-duong-21-1-x...
# 2638  44965482  https://batdongsan.com.vn/ban-dat-xa-phu-cuong...
#
#                                                 Tiêu đề  \
# 0     BÁN MẢNH ĐẤT ĐẸP 1260 m THỊ TRẤN QUỐC OAI TÁCH...
# 1     Tôi chính chủ cần bán nhanh căn hộ dịch vụ 9 t...
# ...
